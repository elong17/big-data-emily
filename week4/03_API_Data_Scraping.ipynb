# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file

import sys 
import os
sys.path.append(os.path.abspath("/Users/Emily/Documents/github/"))

from twitter_key import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[42.354072, -71.065815] # Downtown Boston (Boston Common)
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=30


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:23 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'savingzev.1kyakink.us/client/eVVWe/a…',
#      'expanded_url': 'http://savingzev.1kyakink.us/client/eVVWe/azKjO/aKr28/92Q0P',
#      'indices': [58, 81],
#      'url': 'https://t.co/YTMT3VLogT'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943632442851328,
#   'id_str': '838943632442851328',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'Man On 207-MPH Bicycle Humiliates Ferrari At Dragstrip -- https://t.co/YTMT3VLogT',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jan 21 07:49:39 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 1196,
#    'following': None,
#    'friends_count': 4349,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 822712748228235265,
#    'id_str': '822712748228235265',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3,
#    'location': 'Cambridge, MA',
#    'name': 'Dee Lazzar',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/822712748228235265/1484985081',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/822713000326926338/fihljmPi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822713000326926338/fihljmPi_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'lazzar_dee',
#    'statuses_count': 17884,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:23 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 319264158,
#      'id_str': '319264158',
#      'indices': [0, 15],
#      'name': 'Harry Samuels',
#      'screen_name': 'CuriousCabbage'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943631067209729,
#   'id_str': '838943631067209729',
#   'in_reply_to_screen_name': 'CuriousCabbage',
#   'in_reply_to_status_id': 838943482026799104,
#   'in_reply_to_status_id_str': '838943482026799104',
#   'in_reply_to_user_id': 319264158,
#   'in_reply_to_user_id_str': '319264158',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '@CuriousCabbage the House was affectionately called Dumpster pre-redecoration',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat May 26 09:55:04 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'The Süleyman I to your Abdülhamid II. 19. Philomena Cunk superfan. Harvard Sophomore studying electoral politics, economics, and international relations.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 11372,
#    'follow_request_sent': None,
#    'followers_count': 1038,
#    'following': None,
#    'friends_count': 665,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 590781116,
#    'id_str': '590781116',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 15,
#    'location': 'Cambridge, MA',
#    'name': 'Neil',
#    'notifications': None,
#    'profile_background_color': '000504',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/753816039/1dd1b98221d8611a58cd7cdb976085b0.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/753816039/1dd1b98221d8611a58cd7cdb976085b0.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/590781116/1416692659',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/809208389851025409/mIIdKAzq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/809208389851025409/mIIdKAzq_normal.jpg',
#    'profile_link_color': '94441F',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LifeOfReillly',
#    'statuses_count': 18866,
#    'time_zone': 'London',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 0,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:23 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 308892843,
#      'id_str': '308892843',
#      'indices': [0, 10],
#      'name': 'Richard Slate',
#      'screen_name': 'RichSlate'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943630828138496,
#   'id_str': '838943630828138496',
#   'in_reply_to_screen_name': 'RichSlate',
#   'in_reply_to_status_id': 838943418910932993,
#   'in_reply_to_status_id_str': '838943418910932993',
#   'in_reply_to_user_id': 308892843,
#   'in_reply_to_user_id_str': '308892843',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@RichSlate Agree.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Dec 21 20:39:11 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Proud BC Eagle & stubborn @RedSox fan. Currently training for the @bostonmarathon with #RunDFMC. On a quest to see all 50 state Capitol buildings.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'rundfmc.org/2017/stephstma…',
#        'expanded_url': 'http://www.rundfmc.org/2017/stephstmartin',
#        'indices': [0, 23],
#        'url': 'https://t.co/Y5D4lO7n5Z'}]}},
#    'favourites_count': 8470,
#    'follow_request_sent': None,
#    'followers_count': 1887,
#    'following': None,
#    'friends_count': 2183,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 229212731,
#    'id_str': '229212731',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 144,
#    'location': 'Boston, MA',
#    'name': 'Stephanie St. Martin',
#    'notifications': None,
#    'profile_background_color': 'C1EBCD',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/752804437/240212f77a017ec6915cccddf5de81e5.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/752804437/240212f77a017ec6915cccddf5de81e5.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/229212731/1466161150',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/746387602769649665/n4bFb0BQ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/746387602769649665/n4bFb0BQ_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'StephStMartin',
#    'statuses_count': 11555,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/Y5D4lO7n5Z',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:22 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/tweetlikegiris…',
#      'expanded_url': 'https://twitter.com/tweetlikegiris/status/838408771227516929',
#      'indices': [4, 27],
#      'url': 'https://t.co/NuclDXTwf2'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943630228402178,
#   'id_str': '838943630228402178',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'und',
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sun Mar 05 15:20:02 +0000 2017',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/IL40Ui4vzI',
#       'expanded_url': 'https://twitter.com/TweetLikeGirIs/status/838408771227516929/photo/1',
#       'id': 838408768199213058,
#       'id_str': '838408768199213058',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/C6KgVSUWQAIWalv.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6KgVSUWQAIWalv.jpg',
#       'sizes': {'large': {'h': 278, 'resize': 'fit', 'w': 750},
#        'medium': {'h': 278, 'resize': 'fit', 'w': 750},
#        'small': {'h': 252, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/IL40Ui4vzI'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/IL40Ui4vzI',
#       'expanded_url': 'https://twitter.com/TweetLikeGirIs/status/838408771227516929/photo/1',
#       'id': 838408768199213058,
#       'id_str': '838408768199213058',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/C6KgVSUWQAIWalv.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6KgVSUWQAIWalv.jpg',
#       'sizes': {'large': {'h': 278, 'resize': 'fit', 'w': 750},
#        'medium': {'h': 278, 'resize': 'fit', 'w': 750},
#        'small': {'h': 252, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/IL40Ui4vzI'},
#      {'display_url': 'pic.twitter.com/IL40Ui4vzI',
#       'expanded_url': 'https://twitter.com/TweetLikeGirIs/status/838408771227516929/photo/1',
#       'id': 838408768778031104,
#       'id_str': '838408768778031104',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/C6KgVUeWUAAbZhp.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C6KgVUeWUAAbZhp.jpg',
#       'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 768},
#        'medium': {'h': 1024, 'resize': 'fit', 'w': 768},
#        'small': {'h': 680, 'resize': 'fit', 'w': 510},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/IL40Ui4vzI'}]},
#    'favorite_count': 3443,
#    'favorited': False,
#    'geo': None,
#    'id': 838408771227516929,
#    'id_str': '838408771227516929',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': True,
#    'retweet_count': 1191,
#    'retweeted': False,
#    'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#    'text': 'THIS IS SO CUTE 😍😩 https://t.co/IL40Ui4vzI',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Dec 22 05:50:48 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Tweeting the best female struggles and female relations. Business ✉️: marketing@viralburst.net',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 23,
#     'follow_request_sent': None,
#     'followers_count': 663172,
#     'following': None,
#     'friends_count': 195985,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 443449421,
#     'id_str': '443449421',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 677,
#     'location': ' ',
#     'name': 'Female Struggles',
#     'notifications': None,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000180929128/2o6OJPkR.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000180929128/2o6OJPkR.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/443449421/1401667416',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/473253446205063169/K7acOMV5_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/473253446205063169/K7acOMV5_normal.jpeg',
#     'profile_link_color': '494949',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '456466',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'TweetLikeGirIs',
#     'statuses_count': 1421,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'regular',
#     'url': None,
#     'utc_offset': -18000,
#     'verified': False}},
#   'quoted_status_id': 838408771227516929,
#   'quoted_status_id_str': '838408771227516929',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '😭😭😭 https://t.co/NuclDXTwf2',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jan 18 23:57:40 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '...shit could be worse',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 11205,
#    'follow_request_sent': None,
#    'followers_count': 1294,
#    'following': None,
#    'friends_count': 1812,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 1102323228,
#    'id_str': '1102323228',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 5,
#    'location': 'Lowell, MA',
#    'name': 'Bana🌹Elisee',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1102323228/1486793006',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/832683108306649088/r1yMtHw6_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/832683108306649088/r1yMtHw6_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'BanaElise',
#    'statuses_count': 54016,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:22 +0000 2017',
#   'entities': {'hashtags': [{'indices': [71, 78], 'text': 'WWEHOF'},
#     {'indices': [120, 124], 'text': 'WWE'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1284803784,
#      'id_str': '1284803784',
#      'indices': [3, 18],
#      'name': "The Fan's Podcast",
#      'screen_name': 'TheFansPodcast'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943629062336513,
#   'id_str': '838943629062336513',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 29,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Mar 06 19:39:01 +0000 2017',
#    'entities': {'hashtags': [{'indices': [51, 58], 'text': 'WWEHOF'},
#      {'indices': [100, 104], 'text': 'WWE'}],
#     'media': [{'display_url': 'pic.twitter.com/hPnRuFV3wl',
#       'expanded_url': 'https://twitter.com/TheFansPodcast/status/838836332155793411/photo/1',
#       'id': 838836319157526528,
#       'id_str': '838836319157526528',
#       'indices': [105, 128],
#       'media_url': 'http://pbs.twimg.com/tweet_video_thumb/C6QlMBwUoAAFuVu.jpg',
#       'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/C6QlMBwUoAAFuVu.jpg',
#       'sizes': {'large': {'h': 330, 'resize': 'fit', 'w': 436},
#        'medium': {'h': 330, 'resize': 'fit', 'w': 436},
#        'small': {'h': 257, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/hPnRuFV3wl'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/hPnRuFV3wl',
#       'expanded_url': 'https://twitter.com/TheFansPodcast/status/838836332155793411/photo/1',
#       'id': 838836319157526528,
#       'id_str': '838836319157526528',
#       'indices': [105, 128],
#       'media_url': 'http://pbs.twimg.com/tweet_video_thumb/C6QlMBwUoAAFuVu.jpg',
#       'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/C6QlMBwUoAAFuVu.jpg',
#       'sizes': {'large': {'h': 330, 'resize': 'fit', 'w': 436},
#        'medium': {'h': 330, 'resize': 'fit', 'w': 436},
#        'small': {'h': 257, 'resize': 'fit', 'w': 340},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'animated_gif',
#       'url': 'https://t.co/hPnRuFV3wl',
#       'video_info': {'aspect_ratio': [218, 165],
#        'variants': [{'bitrate': 0,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/tweet_video/C6QlMBwUoAAFuVu.mp4'}]}}]},
#    'favorite_count': 43,
#    'favorited': False,
#    'geo': None,
#    'id': 838836332155793411,
#    'id_str': '838836332155793411',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 29,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Listen up sweat hogs.\n\nRick Rude is going into the #WWEHOF.\n\nNow be quiet while I take my robe off. #WWE https://t.co/hPnRuFV3wl',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Mar 21 02:06:53 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Official Twitter account of The Fan's Podcast network. Visit https://t.co/qJjv82JE9h to access all of our shows and content.",
#     'entities': {'description': {'urls': [{'display_url': 'thefanspodcast.com',
#         'expanded_url': 'http://thefanspodcast.com',
#         'indices': [61, 84],
#         'url': 'https://t.co/qJjv82JE9h'}]},
#      'url': {'urls': [{'display_url': 'thefanspodcast.com',
#         'expanded_url': 'http://thefanspodcast.com/',
#         'indices': [0, 23],
#         'url': 'https://t.co/nuJiaIUZKt'}]}},
#     'favourites_count': 19825,
#     'follow_request_sent': None,
#     'followers_count': 33461,
#     'following': None,
#     'friends_count': 1586,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 1284803784,
#     'id_str': '1284803784',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 281,
#     'location': 'Boston, MA',
#     'name': "The Fan's Podcast",
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000167778020/-GjJE1Z9.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000167778020/-GjJE1Z9.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1284803784/1421260387',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/561291885302398976/V1yuIN7b_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/561291885302398976/V1yuIN7b_normal.png',
#     'profile_link_color': 'F06800',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'A4D6C6',
#     'profile_text_color': '7D8A3A',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'TheFansPodcast',
#     'statuses_count': 93190,
#     'time_zone': 'Atlantic Time (Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/nuJiaIUZKt',
#     'utc_offset': -14400,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @TheFansPodcast: Listen up sweat hogs.\n\nRick Rude is going into the #WWEHOF.\n\nNow be quiet while I take my robe off. #WWE https://t.co/h…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Dec 23 13:38:37 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Follower of Jesus Christ & Future Pro Wrestling Star. Snapchat TheSonOfMars007',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'instagram.com/_TheSonOfMars_/',
#        'expanded_url': 'https://instagram.com/_TheSonOfMars_/',
#        'indices': [0, 23],
#        'url': 'https://t.co/LrHbRyIh71'}]}},
#    'favourites_count': 14866,
#    'follow_request_sent': None,
#    'followers_count': 4813,
#    'following': None,
#    'friends_count': 4745,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 229841541,
#    'id_str': '229841541',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 38,
#    'location': 'Tatooine',
#    'name': 'Heel Turn Haden',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/858340434/51a23df316ac90e0fcc7f07b8f8802a6.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/858340434/51a23df316ac90e0fcc7f07b8f8802a6.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/229841541/1487121098',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/688847157135339520/oFFMTbcd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/688847157135339520/oFFMTbcd_normal.jpg',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': '_TheSonOfMars_',
#    'statuses_count': 23604,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'regular',
#    'url': 'https://t.co/LrHbRyIh71',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:22 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'trib.al/9JUT3W6',
#      'expanded_url': 'http://trib.al/9JUT3W6',
#      'indices': [109, 132],
#      'url': 'https://t.co/YN0ur6TGgX'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943627397185536,
#   'id_str': '838943627397185536',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'Officials are now looking for a legal home for a monkey after it was seized from a residence in Laconia, NH. https://t.co/YN0ur6TGgX',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jan 08 16:30:26 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'NBC Boston is your source for breaking news, weather, traffic, entertainment and sports. Like us on Facebook: https://t.co/zecVNXZQGI',
#    'entities': {'description': {'urls': [{'display_url': 'facebook.com/NBCBoston/',
#        'expanded_url': 'https://www.facebook.com/NBCBoston/',
#        'indices': [110, 133],
#        'url': 'https://t.co/zecVNXZQGI'}]},
#     'url': {'urls': [{'display_url': 'nbcboston.com',
#        'expanded_url': 'http://nbcboston.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/0ELtKtSV1l'}]}},
#    'favourites_count': 43,
#    'follow_request_sent': None,
#    'followers_count': 6337,
#    'following': None,
#    'friends_count': 306,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 4746090250,
#    'id_str': '4746090250',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 135,
#    'location': 'Boston, MA',
#    'name': 'NBC Boston',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4746090250/1483631132',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/765902918583222273/ybHjVegP_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/765902918583222273/ybHjVegP_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'nbcboston',
#    'statuses_count': 5850,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/0ELtKtSV1l',
#    'utc_offset': -28800,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:22 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/jctheresistanc…',
#      'expanded_url': 'https://twitter.com/jctheresistance/status/838927021992337408',
#      'indices': [27, 50],
#      'url': 'https://t.co/y6dyoBZdNP'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943627267170304,
#   'id_str': '838943627267170304',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Mar 07 01:39:23 +0000 2017',
#    'entities': {'hashtags': [{'indices': [111, 125], 'text': 'TheResistance'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 2856030754,
#       'id_str': '2856030754',
#       'indices': [80, 95],
#       'name': 'Kathie Allen',
#       'screen_name': 'kathrynallenmd'}]},
#    'favorite_count': 384,
#    'favorited': False,
#    'geo': None,
#    'id': 838927021992337408,
#    'id_str': '838927021992337408',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 258,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'Breaking news!  Dems officially have a candidate running against Chaffetz! Show @kathrynallenmd some love from #TheResistance. Vote him out!',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Mar 30 02:29:45 +0000 2012',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "#BlizzardOfUS❄️ #TheResistance, #notmypresident #auditthevote #imstillwithher #Resist #GKG #DemForce I don't take orders from Putin or Trump",
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 7288,
#     'follow_request_sent': None,
#     'followers_count': 4848,
#     'following': None,
#     'friends_count': 4481,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 540543234,
#     'id_str': '540543234',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 31,
#     'location': 'United States',
#     'name': 'Jamie #Resistance ❄️',
#     'notifications': None,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/540543234/1483596271',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/822912182207717377/2561Z1OA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822912182207717377/2561Z1OA_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'JCTheResistance',
#     'statuses_count': 9633,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -28800,
#     'verified': False}},
#   'quoted_status_id': 838927021992337408,
#   'quoted_status_id_str': '838927021992337408',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "YES!!! Let's do this! ✊🏽🇺🇸 https://t.co/y6dyoBZdNP",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Aug 09 15:10:19 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Writer. Historian. Intersectional feminist. Comic book fangirl. Gummy bear devourer. Resistance fighter. #twitterstorian #amwriting',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 259,
#    'follow_request_sent': None,
#    'followers_count': 426,
#    'following': None,
#    'friends_count': 611,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 3410514689,
#    'id_str': '3410514689',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 13,
#    'location': 'Boston, MA',
#    'name': 'Tana Mills',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3410514689/1439134557',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/822460693945389060/Y7U8_gbV_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822460693945389060/Y7U8_gbV_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Tana_Writes',
#    'statuses_count': 497,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:21 +0000 2017',
#   'entities': {'hashtags': [{'indices': [35, 44], 'text': 'TeenMom2'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 202495093,
#      'id_str': '202495093',
#      'indices': [8, 22],
#      'name': 'Chelsea DeBoer',
#      'screen_name': 'ChelseaHouska'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943626109595651,
#   'id_str': '838943626109595651',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'More of @ChelseaHouska pug, please #TeenMom2',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Oct 26 23:51:45 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'MMMBOP ✌',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 8521,
#    'follow_request_sent': None,
#    'followers_count': 201,
#    'following': None,
#    'friends_count': 696,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 208269174,
#    'id_str': '208269174',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Boston',
#    'name': 'ash_emm',
#    'notifications': None,
#    'profile_background_color': '642D8B',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/208269174/1353805905',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/749349505372487685/WvBNX01d_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/749349505372487685/WvBNX01d_normal.jpg',
#    'profile_link_color': '6D8EBF',
#    'profile_sidebar_border_color': '65B0DA',
#    'profile_sidebar_fill_color': '7AC3EE',
#    'profile_text_color': 'DB4BAD',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ash_zee',
#    'statuses_count': 10270,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:21 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'trib.al/Hei6bUw',
#      'expanded_url': 'http://trib.al/Hei6bUw',
#      'indices': [68, 91],
#      'url': 'https://t.co/T6EtqLfgu6'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943625262338048,
#   'id_str': '838943625262338048',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': 'Luke Bryan plays Catchphrase with Octavia Spencer and Jimmy Fallon! https://t.co/T6EtqLfgu6',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jun 13 13:49:56 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'An official iHeartCountry station and home of @MrBobbyBones every morning, @JessicaCaLLy in middays, @ColtonBradford every afternoon, and @LanceOnAir at night!',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'thebull1017.iheart.com',
#        'expanded_url': 'http://thebull1017.iheart.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/KAvH8VVmdH'}]}},
#    'favourites_count': 2201,
#    'follow_request_sent': None,
#    'followers_count': 7022,
#    'following': None,
#    'friends_count': 2039,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 2565327282,
#    'id_str': '2565327282',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 55,
#    'location': 'Boston, MA',
#    'name': '101.7 The Bull',
#    'notifications': None,
#    'profile_background_color': '2BABE2',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2565327282/1462828426',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/477494917611003904/NsuiSPSM_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/477494917611003904/NsuiSPSM_normal.png',
#    'profile_link_color': 'F05A28',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'TheBull1017',
#    'statuses_count': 16101,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/KAvH8VVmdH',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:21 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 838943625262288901,
#   'id_str': '838943625262288901',
#   'in_reply_to_screen_name': 'lobean97',
#   'in_reply_to_status_id': 838943542240284672,
#   'in_reply_to_status_id_str': '838943542240284672',
#   'in_reply_to_user_id': 84410383,
#   'in_reply_to_user_id_str': '84410383',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "This is a meme I'm actually 19 omg",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Oct 22 19:59:38 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'prince of emotions / have bear dj my funeral ----- I take pictures sometimes I guess. peep the IG: lobeanphotography',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 21794,
#    'follow_request_sent': None,
#    'followers_count': 486,
#    'following': None,
#    'friends_count': 205,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 84410383,
#    'id_str': '84410383',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 4,
#    'location': 'Boston, MA',
#    'name': 'Logan',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/84410383/1488341553',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838580882231463936/lwbe52Xi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/838580882231463936/lwbe52Xi_normal.jpg',
#    'profile_link_color': '666666',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'lobean97',
#    'statuses_count': 16282,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:21 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 44166798,
#      'id_str': '44166798',
#      'indices': [3, 13],
#      'name': 'Boston Bruins',
#      'screen_name': 'NHLBruins'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943623693615104,
#   'id_str': '838943623693615104',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 4,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Mar 07 02:45:04 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 6,
#    'favorited': False,
#    'geo': None,
#    'id': 838943554953162752,
#    'id_str': '838943554953162752',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 4,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'David Pastrnak heading off for a high stick with at 7:36 of the third.',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jun 02 17:51:52 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Official Twitter Home of the Boston Bruins #NHLBruins',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'BostonBruins.com',
#         'expanded_url': 'http://www.BostonBruins.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/yT63yrOrhF'}]}},
#     'favourites_count': 1194,
#     'follow_request_sent': None,
#     'followers_count': 1167669,
#     'following': None,
#     'friends_count': 36,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 44166798,
#     'id_str': '44166798',
#     'is_translation_enabled': True,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 6989,
#     'location': 'Boston, MA',
#     'name': 'Boston Bruins',
#     'notifications': None,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000097117211/34730a0d4311db3569095da7c016d401.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000097117211/34730a0d4311db3569095da7c016d401.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/44166798/1481734538',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/830860893575663616/OPqZywu1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/830860893575663616/OPqZywu1_normal.jpg',
#     'profile_link_color': '9E0202',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'F1F1F1',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'NHLBruins',
#     'statuses_count': 71959,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/yT63yrOrhF',
#     'utc_offset': -18000,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @NHLBruins: David Pastrnak heading off for a high stick with at 7:36 of the third.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Apr 20 02:57:32 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Twentysomething. Bruins Super Fan. Music Lover. Overall Nerd. Former Dance Team Coach. Event & Wedding Planner. Entertainment Blogger. Engaged!',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 6442,
#    'follow_request_sent': None,
#    'followers_count': 266,
#    'following': None,
#    'friends_count': 372,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 33396990,
#    'id_str': '33396990',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 13,
#    'location': 'New England',
#    'name': 'Sammie',
#    'notifications': None,
#    'profile_background_color': '07090B',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/267339336/xf70b4e17b49cf72aaabed20b7ecf269.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/267339336/xf70b4e17b49cf72aaabed20b7ecf269.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33396990/1426388135',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/817959769294127104/w7-WPRNw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/817959769294127104/w7-WPRNw_normal.jpg',
#    'profile_link_color': 'C34242',
#    'profile_sidebar_border_color': 'BFBFBF',
#    'profile_sidebar_fill_color': 'C9C9C9',
#    'profile_text_color': '1C1F23',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Sammie_Lee17',
#    'statuses_count': 13694,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:21 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/5lEYXmVKTp',
#      'expanded_url': 'https://twitter.com/DebraHar/status/838943622712160256/photo/1',
#      'id': 838943611182014464,
#      'id_str': '838943611182014464',
#      'indices': [0, 23],
#      'media_url': 'http://pbs.twimg.com/media/C6SGxPsWYAAvo37.png',
#      'media_url_https': 'https://pbs.twimg.com/media/C6SGxPsWYAAvo37.png',
# ...
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'Do You Know That Everyone Who Wore Braces -- https://t.co/XrS5w6bIVl',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jan 31 07:36:03 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 664,
#    'following': None,
#    'friends_count': 4442,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 826333205720477696,
#    'id_str': '826333205720477696',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Lowell, MA',
#    'name': 'Josefine Mcelmarry',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/826333205720477696/1485848486',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/826333657337978880/gptYT9Ra_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826333657337978880/gptYT9Ra_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JosefineMcelma4',
#    'statuses_count': 7470,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:19 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943614403284993,
#   'id_str': '838943614403284993',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'touch-a, touch-a, touch me is my hoe anthem',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Jun 20 22:22:45 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'the truth is out there, so bring it in boys',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'Instagram.com/melancholybaby…',
#        'expanded_url': 'http://Instagram.com/melancholybabygurl',
#        'indices': [0, 23],
#        'url': 'https://t.co/Df8h4fAZ2s'}]}},
#    'favourites_count': 34449,
#    'follow_request_sent': None,
#    'followers_count': 3775,
#    'following': None,
#    'friends_count': 306,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 613810537,
#    'id_str': '613810537',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 69,
#    'location': 'Boston, MA',
#    'name': 'chaotic femme',
#    'notifications': None,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/454252000813654016/mmtziQhW.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/454252000813654016/mmtziQhW.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/613810537/1487653196',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/833904339806801920/wV_baO_o_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/833904339806801920/wV_baO_o_normal.jpg',
#    'profile_link_color': '6F7194',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'melancholiababe',
#    'statuses_count': 65109,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/Df8h4fAZ2s',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:19 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 452561829,
#      'id_str': '452561829',
#      'indices': [0, 14],
#      'name': 'Jonathon Kamuf',
#      'screen_name': 'JonathonKamuf'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943614365491202,
#   'id_str': '838943614365491202',
#   'in_reply_to_screen_name': 'JonathonKamuf',
#   'in_reply_to_status_id': 838942175320760320,
#   'in_reply_to_status_id_str': '838942175320760320',
#   'in_reply_to_user_id': 452561829,
#   'in_reply_to_user_id_str': '452561829',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@JonathonKamuf agreed. Pitiful officiating down the stretch',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Sep 13 01:08:31 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Talk about Boston sports, working out, video games and history rants that bore people. Northeast Liberal Elitist',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 195175,
#    'follow_request_sent': None,
#    'followers_count': 4134,
#    'following': None,
#    'friends_count': 3710,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 372576948,
#    'id_str': '372576948',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 134,
#    'location': 'Boston',
#    'name': 'Tribune of the Plebs',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000073128019/694f953ef8992c68ddc1929e34f66117.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000073128019/694f953ef8992c68ddc1929e34f66117.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/372576948/1475529078',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/831019870900871169/DF3CFrO__normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/831019870900871169/DF3CFrO__normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Handsome_Jake_',
#    'statuses_count': 384938,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:19 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 630482170,
#      'id_str': '630482170',
#      'indices': [0, 11],
#      'name': 'Lobstabred',
#      'screen_name': 'Lobstabred'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943614025805824,
#   'id_str': '838943614025805824',
#   'in_reply_to_screen_name': 'Lobstabred',
#   'in_reply_to_status_id': 838928898700242945,
#   'in_reply_to_status_id_str': '838928898700242945',
#   'in_reply_to_user_id': 630482170,
#   'in_reply_to_user_id_str': '630482170',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@Lobstabred Weaken a division rival and gain a good starting back for a 5th?\nAll day long.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Jan 29 02:47:23 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Be water, my friend.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 2902,
#    'follow_request_sent': None,
#    'followers_count': 401,
#    'following': None,
#    'friends_count': 252,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 2316397230,
#    'id_str': '2316397230',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 5,
#    'location': 'Foxboro, MA',
#    'name': 'Pats B. 🏆🏈',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2316397230/1476492288',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/837057802933776384/1dvwT4eJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/837057802933776384/1dvwT4eJ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'iBrycen',
#    'statuses_count': 18999,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Mar 07 02:45:18 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 74741667,
#      'id_str': '74741667',
#      'indices': [3, 19],
#      'name': 'Small Planet',
#      'screen_name': 'SmallPlanetInst'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838943612712804352,
#   'id_str': '838943612712804352',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 3,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Feb 24 15:16:18 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/835146340703301633',
#       'indices': [100, 123],
#       'url': 'https://t.co/SSduokF9KO'}],
#     'user_mentions': []},
#    'favorite_count': 7,
#    'favorited': False,
#    'geo': None,
#    'id': 835146340703301633,
#    'id_str': '835146340703301633',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': "Go Germany! Germany Bans Meat at Official Functions to 'Set a Good Example for Climate Protection'… https://t.co/SSduokF9KO",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Sep 16 14:21:10 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Living democracy, feeding hope. People's think tank founded by @fmlappe and @annalappe",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'smallplanet.org',
#         'expanded_url': 'http://www.smallplanet.org/',
#         'indices': [0, 22],
#         'url': 'http://t.co/FLT91fuqb0'}]}},
#     'favourites_count': 233,
#     'follow_request_sent': None,
#     'followers_count': 2632,
#     'following': None,
#     'friends_count': 1384,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 74741667,
#     'id_str': '74741667',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 135,
#     'location': 'Cambridge, MA',
#     'name': 'Small Planet',
#     'notifications': None,
#     'profile_background_color': 'B2DFDA',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/74741667/1481123209',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/725752553623937024/yHfIFomv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/725752553623937024/yHfIFomv_normal.jpg',
#     'profile_link_color': '93A644',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'FFFFFF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'SmallPlanetInst',
#     'statuses_count': 1736,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/FLT91fuqb0',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>',
#   'text': "RT @SmallPlanetInst: Go Germany! Germany Bans Meat at Official Functions to 'Set a Good Example for Climate Protection' https://t.co/3sHHHW…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jun 21 11:30:49 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'concerned citizen',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 213,
#    'follow_request_sent': None,
#    'followers_count': 85,
#    'following': None,
#    'friends_count': 396,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 321322363,
#    'id_str': '321322363',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 28,
#    'location': '',
#    'name': 'Siem Kew',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/423341377947062272/xKrA8ber_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/423341377947062272/xKrA8ber_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'siemkew',
#    'statuses_count': 3220,
#    'time_zone': 'Brisbane',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 36000,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 1800
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 60
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run_all()
# Out:
# At 0 seconds, added 30 new tweets, for a total of 30
# At 60 seconds, added 30 new tweets, for a total of 60
# At 120 seconds, added 30 new tweets, for a total of 90
# At 180 seconds, added 30 new tweets, for a total of 120
# At 240 seconds, added 30 new tweets, for a total of 150
# At 300 seconds, added 30 new tweets, for a total of 180
# At 360 seconds, added 30 new tweets, for a total of 210
# At 420 seconds, added 30 new tweets, for a total of 240
# At 480 seconds, added 30 new tweets, for a total of 270
# At 540 seconds, added 30 new tweets, for a total of 300
# At 600 seconds, added 30 new tweets, for a total of 330
# At 660 seconds, added 29 new tweets, for a total of 359
# At 720 seconds, added 30 new tweets, for a total of 389
# At 780 seconds, added 30 new tweets, for a total of 419
# At 840 seconds, added 30 new tweets, for a total of 449
# At 900 seconds, added 30 new tweets, for a total of 479
# At 960 seconds, added 30 new tweets, for a total of 509
# At 1020 seconds, added 30 new tweets, for a total of 539
# At 1080 seconds, added 30 new tweets, for a total of 569
# At 1140 seconds, added 30 new tweets, for a total of 599
# At 1200 seconds, added 30 new tweets, for a total of 629
# At 1260 seconds, added 30 new tweets, for a total of 659
# At 1320 seconds, added 30 new tweets, for a total of 689
# At 1380 seconds, added 29 new tweets, for a total of 718
# At 1440 seconds, added 30 new tweets, for a total of 748
# At 1500 seconds, added 30 new tweets, for a total of 778
# At 1560 seconds, added 30 new tweets, for a total of 808
# At 1620 seconds, added 30 new tweets, for a total of 838
# At 1680 seconds, added 30 new tweets, for a total of 868
# At 1740 seconds, added 30 new tweets, for a total of 898
# 898 Tweets retrieved.

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-37ced817fd2a> in <module>()
#      11     full_dir = join(file_dir,file)
#      12     with open(full_dir) as json_data:
# ---> 13         dict = json.load(json_data) # creates a Python dictionary of our json
#      14         if not isinstance(dict, list):
#      15             for key, val in dict.items():
#
# NameError: name 'json' is not defined

# %%
df_tweets.shape
# Out:
# (898, 9)

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['Houston, TX', 'Nepal', 'Boston - MA', 'Commack//Binghamton ',
#        'Boston, Massachusetts', 'Boston, MA', 'Boston', 'Boston,MA',
#        'South Easton MA.', '', '日本の中心で愛を知る', 'Foxboro, MA', 'Boston ',
#        'Burlington, VT', 'Quincy', 'San Diego / D.C. / Tokyo',
#        'Tewksbury, MA', 'Chapel Hill, NC', 'Louisiana, USA',
#        'New Haven, CT', 'Cambridge, MA', 'upstate new york',
#        'Suburbiaville, Ontario', 'boston  ', 'Woburn, MA', 'Chelsea, MA',
#        'Austin Tx', 'Boston, USA', 'Albany, NY', 'Florida',
#        'California, USA', 'Acton, MA', 'Tokyo, Japan & Los Angeles, CA',
#        'Oklahoma', 'Boulder, CO', 'Auburndale, MA', 'Quincy, MA',
#        'Marblehead, MA', 'Long Island, New York', '#STL ', 'Lowell, MA',
#        'Waltham, MA', 'The block', 'just outside of Boston, MA', '横浜',
#        'Woodbridge', 'NYC, Newtown, &theWhoscow. ', 'Global', 'Salem, MA',
#        'Boston,MA.', 'En la isla mas bonita ', 'East Bridgewater, MA',
#        'Somerville, MA', 'Boston MA', 'land of oobis', 'Saugus Ma',
#        'トーマ@条約', 'Boston Massachusetts', 'Maine, New England,USA, Earth ',
#        'Wisconsin, USA', 'Gillette Stadium', 'Lowell', 'Lawrence, MA',
#        'Thomaston, CT', 'Washington, DC', 'Westhampton, MA, USA',
#        'Lowell, MA, USA', 'Hiding in the bathroom', 'Follow Me pls ',
#        'cash.me/$KeithBStill ', 'Fairfax, VA', 'petawawa, ontario',
#        'North of Boston, MA', 'Atlanta, GA', 'Peabody, MA',
#        'PAISLEY PARK/THE FROZEN TUNDRA', 'Newton, MA 02461',
#        'Brookline, MA', 'Los Angeles, CA', 'illadelph. too.wun.phive',
#        '언젠가 바다가 보이는 방에서', 'Essex, UK', 'gjobateh@gmail.com', 'Revere Ma',
#        'Fort Worth, TX', 'State College, PA', 'Minding My Business',
#        'Trash', 'Weenie Hut General', 'Boston, Ma.', 'wingo city',
#        'Portland, OR', 'boston', 'Boston/Brockton', 'United States',
#        'New York', 'Medford', 'Charleston, SC',
#        'Framingham State University', 'Saugus, MA', 'Spiece',
#        'Western Mass', 'Greater Boston', 'ハーバード大学', 'wicked little town',
#        'Boston Ma ', 'Gurgaon', 'Lynn, MA', 'Bean-Town/Salem World',
#        '22 Union Square, Somerville', 'Newton, MA', 'Billerica, MA',
#        'cambridge, ma', 'Norwood, MA', 'Subang Jaya, Selangor. ',
#        'Sacramento, CA', '佐世保鎮守府', 'Winchester, MA', 'Iowa City, IA',
#        'Home ', 'Florida, USA', 'boston, ma', '[they pronouns] ',
#        'Brockton, MA ', 'Kota Makassar, SulSel', 'Springfield, MA',
#        'てぃんぽい村', 'Dakor, India', 'Tatooine, Hoth, CoffeeShops',
#        'Argentina', 'nj', 'Bozeman, MT', 'FLA to MA Eventually',
#        'Providence, RI', "bitchin'", 'somewhere cold', 'Virginia, USA',
#        'Here and Now', 'Dedham, MA', 'North Andover, MA', 'Alexandria, VA',
#        'Brasil', 'worthless & irrelevant', '7 ELEVEN❤️',
#        'E. Bridgewater, MA/Boston, MA', 'Trailwood, Tx',
#        'Massachusetts, USA', 'Ho Chi Minh, Vietnam', 'Home',
#        'Braintree, MA', 'Rhode Island, USA', 'Capital Wasteland',
#        'andy-small.com/irtmforums', 'Columbia Falls, Montana', 'Lowell ',
#        'georgia ', 'Boston,Ma', 'California   =', 'Lothlorien', '480',
#        'WF, TX | Stillwater, OK ', 'Wakefield , MA', 'Texcoco, México',
#        'Framingham MA', 'Oxford, OH', 'Charlottesville, VA',
#        'North Bergen, NJ', 'The Lone Star State',
#        'Somerville, Massachusetts', 'New England', 'Boston, MA & Jamaica ',
#        'mhk', 'Down South via Up North', 'Washington D.C.',
#        'North Haven, CT', 'JMU', 'Brockton, MA', 'Newton', 'Chicago, IL',
#        ' suff | THE Sacred Heart U', 'Malden, MA', "meaghan's",
#        'Phoenix, AZ/ Tempe, AZ', 'Morganville, TX',
#        'Kolter Lab, Boston, MA', 'Foxborough Massachusetts ', 'unknown',
#        'Boston. Taunton.', 'Manhattan, NY', 'Chicago, IL ✈️ Albany, NY',
#        'Marlborough, MA', 'Cambridge MA', 'Revere, MA', 'Hyrule',
#        'Cape Coral, FL', 'Fenway Park', 'Queens College ',
#        'Near Boston, MA', 'Holbrook, MA', 'arizona', 'New Jersey, USA',
#        'New York, NY', 'Babe USA', 'Connecticut, USA', 'South Boston, MA',
#        'Pittsburgh, PA', 'Bogotá, Colombia', 'Suffolk University',
#        'Rockport, MA', 'lawrence, Ma', 'Merrick, NY', 'Chicago',
#        'North Liberty, IA', 'Worldwide', 'KC', 'UW Sharkside ',
#        'Counting my blessings', 'Hull, MA', ' ', 'Melrose, MA',
#        'Plattsburgh, NY', 'Acton, United States', 'Minnesota',
#        'Seattle/Boston', 'Millis, MA  ', 'Hermosillo, Sonora', 'Colombia',
#        'dadu sindh pakistan',
#        'Livonia, MI, most likely in a gym/field/rink somewhere',
#        'Harvard Law School', 'around the neighborhood', 'boston ',
#        'Nashville, TN', 'CT', 'Sec Q Row 3 or Sec TT row 3',
#        'Entre Ríos, Argentina', 'Winona, MN', 'Seattle, SFO ',
#        'east dedham', 'Maine', 'Lowell, MA ✈️ Springhill, FL',
#        'Boston University ', 'クレヨン王国', 'danvers',
#        'In an art house somewhere', 'Brighton, MA', 'Nae York City ',
#        'lowell', 'Framingham, MA', 'a parallel universe', 'Tempe, AZ',
#        '道民', 'Rumbling toward truth.', 'Kenya', 'kcmo', 'Brockton,Ma',
#        'Lawrence MA', 'Encouraging survivors to speak',
#        'MIT, Cambridge, MA, USA', 'Samadhi', 'Hull,MA', 'Medford, MA',
#        ' ♒️ ATLien', 'Woburn, MA by way of Attleboro', 'Nj',
#        'outside boston', 'California', 'Malden, Massachusetts',
#        'EAST COAST', 'Stittsvegas, ON', 'Reading, MA',
#        'I Block Trolls & Report Porn!', 'Boston College',
#        'South Boston ➡️⬅️Gillette ', 'Harvard University', 'Massachusetts',
#        'New Brunswick, NJ', 'Boston, Ma', 'Coastal Massachusetts',
#        'Manchester, NH', 'ÜT: 40.738941,-74.031116', 'Pembroke, MA',
#        'Chelmsford, MA', 'AraCity', 'Pfalz!', 'Canton MA', 'Weymouth, MA',
#        '100 Legends Way Boston, MA', 'Walt Disney World',
#        'Boston, MA & Drakes Island, ME', 'Natick, MA',
#        "N 30°1' 0'' / W 90°16' 0''", '阪外露', 'here', 'Mansfield, MA',
#        'Caracas-Venezuela', 'Palo Alto, CA', 'Boston Bruins',
#        'Buffalo, NY', 'The Land, NC', 'traphouse',
#        'somehwere being a fatass', 'Hyderabad, India', 'The AdversAerie',
#        'Wakefield, MA', 'St. Paul, MN', 'VA', 'lynn', 'RCTID', '北方',
#        'Turn On Notifcations', 'Palencia, Spain',
#        'Littleton, Massachusetts', 'Your screen', 'WestSide, Boston 32Ave',
#        'NYC // Hogwarts // Concerts', '인장-뽂쟈', 'Oregon, IL',
#        'MurdaMa$$ 96 #BE4$TCOAST 978', 'South Boston', '  Boston ',
#        'Bahston•Not really ¯\\_(ツ)_/¯', 'Class of 2017  3 11 19 30 42 ',
#        'Norwood, Massachusetts', 'BOS', '† 6º LU – 11º LS †',
#        'New Hampshire, USA', 'The new Twilight Zone=USA', ':^( ',
#        'Boston Ma', 'World', 'Grand Rapids, MI', 'Terra',
#        'Argentina, Córdoba', 'Tatooine', 'Dorchester, Mass',
#        'St. louis, MO', 'Boston, Ma.  USA', '헤더_어화동동님 / 인장_굷님'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort('Count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-068bfb94e0b2> in <module>()
# ----> 1 grouped_tweets = df_tweets.groupby('location')
#       2 count_tweets = grouped_tweets['location'].count()
#       3 df_count_tweets = count_tweets.to_frame()
#       4 df_count_tweets.columns = ['Count']
#       5 df_count_tweets.index.names = ['Location']
#
# NameError: name 'df_tweets' is not defined

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
#                               tweet_id      lat      lon  \
# 838948458631319552  838948458631319552 -71.2356  42.3765
# 838950726319636484  838950726319636484 -71.0611  42.2837
#
#                                                               content  \
# 838948458631319552  Interested in a #job in #Waltham, MA? This cou...
# 838950726319636484  Opened report via iphone at 37 Carruth St, Dor...
#
#                        location        user  \
# 838948458631319552  Boulder, CO  3562102752
# 838950726319636484   Boston, MA  3413390356
#
#                                                            raw_source  \
# 838948458631319552  {'geo': {'coordinates': [42.3764852, -71.23561...
# 838950726319636484  {'geo': {'coordinates': [42.28372525, -71.0610...
#
#                    data_point                            time
# 838948458631319552       none  Tue Mar 07 03:04:34 +0000 2017
# 838950726319636484       none  Tue Mar 07 03:13:34 +0000 2017

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_boston = ['Boston - MA','Boston, Massachusetts','Boston, MA','Boston', 'Boston ','boston  ','Boston, USA','Boston,MA.','Boston MA', 'Boston Massachusetts','boston','Boston, Ma.','Boston/Brockton','Boston Ma ','boston, ma','E. Bridgewater, MA/Boston, MA','Boston,Ma','Boston, MA & Jamaica ','Kolter Lab, Boston, MA','Boston. Taunton.','boston ','Boston University ','South Boston ➡️⬅️Gillette ','Boston College','Boston, Ma','100 Legends Way Boston, MA','Boston, MA & Drakes Island, ME','Boston Bruins','WestSide, Boston 32Ave','South Boston','  Boston ','Boston Ma','Boston, Ma.  USA','Dorchester, Mass','BOS','']

df_tweets['location'].replace(variations_of_boston, 'Boston, MA')
# Out:
# 838948220952801280                  Houston, TX
# 838947441068007424                        Nepal
# 838943924890796033                   Boston, MA
# 838945942103605250         Commack//Binghamton
# 838944668968693761                   Boston, MA
# 838950741142274050                   Boston, MA
# 838947713517502465                   Boston, MA
# 838949717367209986                    Boston,MA
# 838949482733662208                   Boston, MA
# 838946186774130693             South Easton MA.
# 838950738462027778                   Boston, MA
# 838947459619434499                   日本の中心で愛を知る
# 838943614025805824                  Foxboro, MA
# 838943622712160256                   Boston, MA
# 838944426462445569                   Boston, MA
# 838947706118750208               Burlington, VT
# 838950734502711297                       Quincy
# 838945179017089029                   Boston, MA
# 838950995463823360                   Boston, MA
# 838949484209983492                   Boston, MA
# 838948467837911040                   Boston, MA
# 838950483616112644     San Diego / D.C. / Tokyo
# 838945428053839872                Tewksbury, MA
# 838946937629966336                   Boston, MA
# 838945943500259329              Chapel Hill, NC
# 838949473770426368               Louisiana, USA
# 838948979517816839                New Haven, CT
# 838943908872732676                   Boston, MA
# 838948711359266817                Cambridge, MA
# 838943903604686850             upstate new york
#                                 ...
# 838948471029788672           New Hampshire, USA
# 838950725979897856                Brockton, MA
# 838949733859225600                   Boston, MA
# 838944678997344257    The new Twilight Zone=USA
# 838944937446096896                         :^(
# 838948971334807552                   Boston, MA
# 838949479747358725                        World
# 838944674446512133             Grand Rapids, MI
# 838949980077424640                   Boston, MA
# 838949985764925441                        Terra
# 838945941017231361                   Boston, MA
# 838949989384617984                   Boston, MA
# 838943631067209729                Cambridge, MA
# 838946697317388288           Argentina, Córdoba
# 838943629062336513                     Tatooine
# 838948219837104128                   Boston, MA
# 838944153606238210                   Boston, MA
# 838949474839965699                   Boston, MA
# 838944175794110464                   Boston, MA
# 838946194365767680                   Boston, MA
# 838945433737117696                   Boston, MA
# 838946447856840704              Los Angeles, CA
# 838948724881633280                St. louis, MO
# 838944152456855552                   Boston, MA
# 838945183991463939                   Boston, MA
# 838950233644085250                   Boston, MA
# 838950973477371904                   Boston, MA
# 838944680171737088                   Boston, MA
# 838947953167360000             헤더_어화동동님 / 인장_굷님
# 838949475691421697                Brookline, MA
# Name: location, dtype: object

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
